# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Stock Market Tracking.csv")
df.head()
# Out:
#            Stock Market cap (in Rs Cr.) Current price PE Ratio 52 Week High  \
# 0            TCS             1234544.52        3374.2    30.43       4045.5
# 1            HUL              616301.33        2620.6    63.81       2741.6
# 2         Airtel              441027.40         764.6    65.86       860.55
# 3  Bajaj Finance              361172.64          5977    36.52         8045
# 4   Asian Paints              278960.10          2912    76.19       3582.9
#
#   % Below 52 week high 52 Week Low % Above 52 Week low  \
# 0               16.59%        2926              15.32%
# 1                4.41%     1901.55              37.81%
# 2               11.15%      628.75              21.61%
# 3               25.71%        5220              14.50%
# 4               18.73%        2560              13.75%
#
#   Yesterday Closing Price % Change  ...  Unnamed: 15  Unnamed: 16  \
# 0                  3334.6    1.19%  ...          NaN          NaN
# ...

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['Stock', 'Market cap (in Rs Cr.)', 'Current price', 'PE Ratio',
#        '52 Week High', '% Below 52 week high', '52 Week Low',
#        '% Above 52 Week low', 'Yesterday Closing Price', '% Change',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
df = df.drop(columns=['Unnamed: 10', 'Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17',
                      'Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23', 'Unnamed: 24'])
column_names = df.columns
print(column_names)
# Out:
# Index(['Stock', 'Market cap (in Rs Cr.)', 'Current price', 'PE Ratio',
#        '52 Week High', '% Below 52 week high', '52 Week Low',
#        '% Above 52 Week low', 'Yesterday Closing Price', '% Change'],
#       dtype='object')

# %%
df.head()
# Out:
#            Stock Market cap (in Rs Cr.) Current price PE Ratio 52 Week High  \
# 0            TCS             1234544.52        3374.2    30.43       4045.5
# 1            HUL              616301.33        2620.6    63.81       2741.6
# 2         Airtel              441027.40         764.6    65.86       860.55
# 3  Bajaj Finance              361172.64          5977    36.52         8045
# 4   Asian Paints              278960.10          2912    76.19       3582.9
#
#   % Below 52 week high 52 Week Low % Above 52 Week low  \
# 0               16.59%        2926              15.32%
# 1                4.41%     1901.55              37.81%
# 2               11.15%      628.75              21.61%
# 3               25.71%        5220              14.50%
# 4               18.73%        2560              13.75%
#
#   Yesterday Closing Price % Change
# 0                  3334.6    1.19%
# 1                 2590.05    1.18%
# 2                   756.9    1.02%
# ...

# %% [markdown]
# ###  Task 1 : First Create a New Sub Sheet & Fetch all the Data from the Sheet called "Data Set" where Data from the PE Ratio is not Blank & PE Ratio < 100 using Query Function  and sort the data by Descending of Market Cap Amount.

# %%
#=QUERY('Data Set'!A:K, "SELECT * WHERE D IS NOT NULL AND D < 100 ORDER BY B DESC", 1)


# Convert 'PE Ratio' column to numeric
df['PE Ratio'] = pd.to_numeric(df['PE Ratio'], errors='coerce')
# Filter the DataFrame to select rows where PE Ratio is not blank and less than 100
filtered_df = df[df['PE Ratio'].notnull() & (df['PE Ratio'] < 100)]
sorted_df = filtered_df.sort_values(by='Market cap (in Rs Cr.)', ascending=False)
sorted_df.to_excel('task1.xlsx', index=False)
sorted_df.sample(10)
# Out:
#                  Stock Market cap (in Rs Cr.) Current price  PE Ratio  \
# 63    Indraprastha Gas               29162.03        416.85     17.03
# 204         Kotak Bank              354002.54        1780.5     25.87
# 213             Crisil               22166.90          3020     38.36
# 2               Airtel              441027.40         764.6     65.86
# 24           SBI Cards               74336.76        786.05     35.28
# 121    Sonata Software                8104.16           582     19.25
# 31        Berger Paint               54643.26           564     57.95
# 138  Heidelberg Cement                4230.87         186.9     23.18
# 167     Bank of Baroda               95565.88         184.9      9.72
# 57                 MRF               38048.54         89700     66.97
#
#     52 Week High % Below 52 week high 52 Week Low % Above 52 Week low  \
# 63        466.65               10.67%       322.1              29.42%
# ...

# %%
sorted_df.isnull().sum()
# Out:
# Stock                      0
# Market cap (in Rs Cr.)     0
# Current price              0
# PE Ratio                   0
# 52 Week High               0
# % Below 52 week high       0
# 52 Week Low                0
# % Above 52 Week low        0
# Yesterday Closing Price    0
# % Change                   0
# dtype: int64

# %%
sorted_df.shape
# Out:
# (190, 10)

# %% [markdown]
# ### Task 2 :  Now Create 2 Columns of Industry & NSE/BSE Code & Fetch Data from the Second Sheet with Vlookup, Make sure the Vlookup Formula is used with "ARRAYFORMULA" meaning formula will be written only once but will be applicable throughout the column, Also make sure the Formula of Vlookup will be applied only until when data is there in the column, handle this with IF CONDITIONS in that same formula.

# %%
# =IF(A1="", "", ARRAYFORMULA(VLOOKUP(A2:A, 'Company Info'!A:B, 2, FALSE)))

industry_df = pd.read_csv("NSEBSE Code.csv", skiprows=1)
industry_df.columns = industry_df.iloc[0]
industry_df = industry_df.drop(0)
industry_df = industry_df.reset_index(drop=True)
# Perform a vlook operation or merge operation with the first DataFrame
merged_df1 = pd.merge(sorted_df, industry_df, on='Stock', how='left')
# Fill missing values in the 'Industry' and 'NSE/BSE Code' columns with empty strings
merged_df1['Industry'] = merged_df1['Industry'].fillna('')
merged_df1['NSE/BSE Code'] = merged_df1['NSE/BSE Code'].fillna('')
# Save the merged DataFrame to a new CSV file
merged_df1.to_excel('task2.xlsx', index=False)
merged_df1.head()
# Out:
#                Stock Market cap (in Rs Cr.) Current price  PE Ratio  \
# 0     Tanla Platform                9951.42         731.9     19.49
# 1  Amara Raja Batter                9847.33         576.5     17.05
# 2      Tech Mahindra               97631.02        1002.8     16.80
# 3              Dabur               96383.94           544     55.79
# 4             Cyient                9606.15           876     19.98
#
#   52 Week High % Below 52 week high 52 Week Low % Above 52 Week low  \
# 0       2094.4               65.05%       584.8              25.15%
# 1       668.15               13.72%      438.05              31.61%
# 2         1751               42.73%       943.7               6.26%
# 3       610.75               10.93%      482.25              12.80%
# 4      1051.85               16.72%         720              21.67%
#
#   Yesterday Closing Price % Change               Industry NSE/BSE Code
# 0                   724.3    1.05%             Technology   BOM:532790
# ...

# %%
merged_df1.shape
# Out:
# (190, 12)

# %% [markdown]
# ### Task 3 : Now Create 2 More Columns at the End with the Heading "Bear Mode 1" & "Bear Mode 2" Bear Mode 1 Condition : Use IF Condition to print "Yes" if % Change from 52 Week High > 30 else "No" Bear Mode Condition 2 : Use IF Condition to print "Yes" if % Change from 52 Week Low < 30 else "No"

# %%
# Convert 'Current price' and '52 Week Low' columns to numeric
merged_df1[['Current price', '52 Week High', '52 Week Low']] = merged_df1[['Current price', '52 Week High','52 Week Low']].apply(pd.to_numeric, errors='coerce')
merged_df1['% Change from 52 Week High'] = ((merged_df1['Current price'] - merged_df1['52 Week High']) / merged_df1['52 Week High']) * 100
merged_df1['% Change from 52 Week Low'] = ((merged_df1['Current price'] - merged_df1['52 Week Low']) / merged_df1['52 Week Low']) * 100
merged_df1.sample(10)
# Out:
#                      Stock Market cap (in Rs Cr.)  Current price  PE Ratio  \
# 28    craftsman automation                7324.34        3465.10     35.75
# 126          Paras Defense                2250.91         577.80     67.14
# 40        Amber Enterprise                6297.53        1870.00     49.07
# 188             Bajaj Auto              101964.86        3602.45     17.79
# 71   Balkrishna Industries               43195.87        2229.00     30.72
# 9                 Dr Reddy                 880.69        4323.50     23.13
# 67          Lux Industries                4564.43        1524.70     17.12
# 45              MapmyIndia                5752.71        1071.50     65.24
# 62                    HDFC              478914.70        2619.25     19.81
# 164    Indiamart Intermesh               13709.81        4477.00     56.62
#
#      52 Week High % Below 52 week high  52 Week Low % Above 52 Week low  \
# ...

# %%
# Bear Mode 1
merged_df1['Bear Mode 1'] = merged_df1['% Change from 52 Week High'].apply(lambda x: 'Yes' if x > 30 else 'No')
# Bear Mode 2
merged_df1['Bear Mode 2'] = merged_df1['% Change from 52 Week Low'].apply(lambda x: 'Yes' if x < 30 else 'No')
# Display the DataFrame to verify the changes
merged_df1.head(5)
# Out:
#                Stock Market cap (in Rs Cr.)  Current price  PE Ratio  \
# 0     Tanla Platform                9951.42          731.9     19.49
# 1  Amara Raja Batter                9847.33          576.5     17.05
# 2      Tech Mahindra               97631.02         1002.8     16.80
# 3              Dabur               96383.94          544.0     55.79
# 4             Cyient                9606.15          876.0     19.98
#
#    52 Week High % Below 52 week high  52 Week Low % Above 52 Week low  \
# 0       2094.40               65.05%       584.80              25.15%
# 1        668.15               13.72%       438.05              31.61%
# 2       1751.00               42.73%       943.70               6.26%
# 3        610.75               10.93%       482.25              12.80%
# 4       1051.85               16.72%       720.00              21.67%
#
#   Yesterday Closing Price % Change               Industry NSE/BSE Code  \
# ...

# %%
# Create Stock Status column
merged_df1['Stock Status'] = ''
# Apply conditions
merged_df1.loc[(df['PE Ratio'] < 65) & (merged_df1['Bear Mode 1'] == 'No') & (merged_df1['Bear Mode 2'] == 'No'), 'Stock Status'] = 'Good Stock'
# Display the DataFrame to verify the changes
merged_df1.head(5)
# Out:
#                Stock Market cap (in Rs Cr.)  Current price  PE Ratio  \
# 0     Tanla Platform                9951.42          731.9     19.49
# 1  Amara Raja Batter                9847.33          576.5     17.05
# 2      Tech Mahindra               97631.02         1002.8     16.80
# 3              Dabur               96383.94          544.0     55.79
# 4             Cyient                9606.15          876.0     19.98
#
#    52 Week High % Below 52 week high  52 Week Low % Above 52 Week low  \
# 0       2094.40               65.05%       584.80              25.15%
# 1        668.15               13.72%       438.05              31.61%
# 2       1751.00               42.73%       943.70               6.26%
# 3        610.75               10.93%       482.25              12.80%
# 4       1051.85               16.72%       720.00              21.67%
#
#   Yesterday Closing Price % Change               Industry NSE/BSE Code  \
# ...

# %%
merged_df1.sample(10)
# Out:
#                      Stock Market cap (in Rs Cr.)  Current price  PE Ratio  \
# 89          Honeywell Auto               35109.69       39710.00     91.84
# 159             Nippon AMC               15766.34         252.60     23.69
# 173          Happiest Mind               12642.15         885.05     59.08
# 29   Metropolis Healthcare                7063.23        1380.05     45.85
# 24               SBI Cards               74336.76         786.05     35.28
# 152  Goldiam International                1794.80         165.55     17.83
# 37         Praj Industries                6488.72         353.00     35.19
# 186     Mannapuran Finance               10287.93         121.55      8.70
# 138       Ultratech Cement              208975.80        7244.95     31.35
# 165            Affle India               13659.00        1024.00     55.83
#
#      52 Week High % Below 52 week high  52 Week Low % Above 52 Week low  \
# ...

# %%
merged_df1.to_excel('task3.xlsx', index=False)

# %%
good_stocks = merged_df1[merged_df1['Stock Status'] == 'Good Stock']['Stock'].tolist()
print(good_stocks)
# Out:
# ['Amara Raja Batter', 'Godrej Consumer', 'Astrazeneca', 'Eicher Motor', 'Poly Medicure Ltd', 'Granules India', 'ICICI Bank', 'Cera Sanitaryware', 'Data Pattern', 'Yesbank', 'Gujarat Ambuja Export', 'MTAR', 'PI industries', 'TVS', 'Abbott India', 'Balkrishna Industries', 'Polycab', 'Honeywell Auto', 'Somany home innovation ltd', 'Astec Lifesciences', 'Mold tech', 'APL Apollo', 'Supreme Industries', 'Gujarat Florochemical', 'Federal Bank', 'Axis Bank', 'Sun pharma', 'Sumitomo Chemicals', 'J K Cement', 'LIC Housing Finance', 'Titan', 'Ultratech Cement', 'KPIT', 'Fine Organics', 'Tata Steel', 'SBI life Insurance', 'KEI Industries', 'Finolex Industries', 'Ambuja Cement', 'Mannapuran Finance', 'UTI AMC']

# %%
good_stocks_df = merged_df1[merged_df1['Stock Status'] == 'Good Stock'][['Stock', 'Stock Status']]
print(good_stocks_df)
# Out:
#                           Stock Stock Status
# 1             Amara Raja Batter   Good Stock
# 6               Godrej Consumer   Good Stock
# 8                   Astrazeneca   Good Stock
# 11                 Eicher Motor   Good Stock
# 13            Poly Medicure Ltd   Good Stock
# 19               Granules India   Good Stock
# 23                   ICICI Bank   Good Stock
# 33            Cera Sanitaryware   Good Stock
# 39                 Data Pattern   Good Stock
# 44                      Yesbank   Good Stock
# 48        Gujarat Ambuja Export   Good Stock
# 55                         MTAR   Good Stock
# 58                PI industries   Good Stock
# 64                          TVS   Good Stock
# 65                 Abbott India   Good Stock
# 71        Balkrishna Industries   Good Stock
# 78                      Polycab   Good Stock
# 89               Honeywell Auto   Good Stock
# 91   Somany home innovation ltd   Good Stock
# 92           Astec Lifesciences   Good Stock
# ...

# %%
good_stocks_df.head(5)
# Out:
#                 Stock Stock Status
# 1   Amara Raja Batter   Good Stock
# 6     Godrej Consumer   Good Stock
# 8         Astrazeneca   Good Stock
# 11       Eicher Motor   Good Stock
# 13  Poly Medicure Ltd   Good Stock

# %%
good_stocks_df.shape
# Out:
# (41, 2)

# %%
good_stocks_df.to_excel('task3.1.xlsx', index=False)

# %% [markdown]
# ### Task 4 : Now create a new sheet & fetch all Data where Stock Status = 'Good Stock' which will be your Final Organized Data Source so Create Proper Formatting to this Sheet like the Data Source Sheet & also add Appropriate Conditional Formatting Colour Scales.

# %%
select_df = pd.read_excel('task2.xlsx')
selected_data = select_df[select_df['Stock'].isin(good_stocks)]
print(selected_data)
# Out:
#                           Stock  Market cap (in Rs Cr.)  Current price  \
# 1             Amara Raja Batter                 9847.33         576.50
# 6               Godrej Consumer                93678.86         916.75
# 8                   Astrazeneca                 8815.82        3515.05
# 11                 Eicher Motor                86543.23        3164.90
# 13            Poly Medicure Ltd                 8584.67         891.50
# 19               Granules India                 7705.43         318.60
# 23                   ICICI Bank                 7451.47         873.25
# 33            Cera Sanitaryware                 6919.97        5294.00
# 39                 Data Pattern                 6367.83        1227.10
# 44                      Yesbank                57937.94          20.15
# 48        Gujarat Ambuja Export                 5515.52         241.50
# 55                         MTAR                 5182.99        1688.15
# ...

# %%
selected_data.head(5)
# Out:
#                 Stock  Market cap (in Rs Cr.)  Current price  PE Ratio  \
# 1   Amara Raja Batter                 9847.33         576.50     17.05
# 6     Godrej Consumer                93678.86         916.75     58.81
# 8         Astrazeneca                 8815.82        3515.05     95.35
# 11       Eicher Motor                86543.23        3164.90     37.12
# 13  Poly Medicure Ltd                 8584.67         891.50     61.12
#
#     52 Week High % Below 52 week high  52 Week Low % Above 52 Week low  \
# 1         668.15               13.72%       438.05              31.61%
# 6         955.65                4.07%       660.20              38.86%
# 8        3619.70                2.89%      2437.75              44.19%
# 11       3889.65               18.63%      2159.55              46.55%
# 13       1044.40               14.64%       652.30              36.67%
#
#     Yesterday Closing Price % Change               Industry NSE/BSE Code
# ...

# %%
selected_data.to_excel('task4.xlsx', index=False)

# %% [markdown]
# ### Task 5 : Create a Pivot Table Report as Follows :
#
# - Industry wise Total Count of Companies
# - Industry wise Average Market Cap
# - Industry wise sum of Market Cap

# %%
pivot_table_count = pd.pivot_table(selected_data, 
                                    index='Industry',
                                    values='Stock',
                                    aggfunc='count',
                                    fill_value=0)

# Rename the column for better readability
pivot_table_count.columns = ['Total Count of Companies according to Industry']
# print(pivot_table_count)
pivot_table_count.head(100)
# Out:
#                        Total Count of Companies according to Industry
# Industry
# AMC                                                                 1
# Agrochemical                                                        2
# Automobile                                                          2
# Automobile Ancilliary                                               2
# Bank                                                                4
# Cement                                                              3
# Ceramics                                                            1
# Chemical                                                            1
# Consumer Electrical                                                 2
# Defence                                                             1
# FMCG                                                                1
# Healthcare                                                          1
# ...

# %%
pivot_table_count.to_excel('task5.1.xlsx')

# %%
pivot_table_count2 = pd.pivot_table(selected_data, 
                                    index='Industry',
                                    values='Market cap (in Rs Cr.)',
                                    aggfunc='mean',
                                    fill_value=0)

# Rename the column for better readability
pivot_table_count2.columns = ['Average Market Cap based on Industry']
print(pivot_table_count2)
pivot_table_count2.head()
# Out:
#                        Average Market Cap based on Industry
# Industry
# AMC                                              10284.2900
# Agrochemical                                     37056.7300
# Automobile                                       67077.0450
# Automobile Ancilliary                            22478.5100
# Bank                                             95470.2975
# Cement                                          111467.2500
# Ceramics                                          6919.9700
# Chemical                                         17277.2000
# Consumer Electrical                              26455.7350
# Defence                                           5182.9900
# FMCG                                             93678.8600
# Healthcare                                        8584.6700
# IT                                               18827.9500
# Infrastructure                                  147293.6000
# ...

# %%
pivot_table_count2.to_excel('task5.2.xlsx')

# %%
pivot_table_count3 = pd.pivot_table(selected_data, 
                                    index='Industry',
                                    values='Market cap (in Rs Cr.)',
                                    aggfunc='sum',
                                    fill_value=0)

# Rename the column for better readability
pivot_table_count3.columns = ['SUM of Market Cap based on Industry']
print(pivot_table_count3)
pivot_table_count3.head()
# Out:
#                        SUM of Market Cap based on Industry
# Industry
# AMC                                               10284.29
# Agrochemical                                      74113.46
# Automobile                                       134154.09
# Automobile Ancilliary                             44957.02
# Bank                                             381881.19
# Cement                                           334401.75
# Ceramics                                           6919.97
# Chemical                                          17277.20
# Consumer Electrical                               52911.47
# Defence                                            5182.99
# FMCG                                              93678.86
# Healthcare                                         8584.67
# IT                                                18827.95
# Infrastructure                                   147293.60
# Insurance                                        130568.99
# ...

# %%
pivot_table_count3.to_excel('task5.3.xlsx')
